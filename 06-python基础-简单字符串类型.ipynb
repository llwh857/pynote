# %% [markdown]
# python基础(重点)-字符串类型
# ---
#  - 什么是字符串：
#
#   > 一个或者多个文字的组合、汉字(你好，世界)、英文（hello world）、日语（こんにちは世界），都属于字符串
#
#
#  - 账户登录与注册
#
#  >  ![image.png](attachment:fb7c561a-7e8a-4031-99ee-c08df1988aba.png)
#
#  - 输入的搜索
#
#  > ![image.png](attachment:c8f46bce-8d87-4797-bf29-f031086497eb.png)
#
#
#
# - 宝贝页面：
# > ![image.png](attachment:476c3fd7-4134-4254-8d59-ca6a265c9516.png)
#
#
#
#  - 在程序中字符串是什么 应该怎样表示的？
#   > 字符串类型：是string的前三个字母 str
#
#   > 在代码中和数值类型变量的定义是相似的， 都是   **名称  = 值**    使用单引号和双引号括起来’content‘，  “content”
#
#   > 如果字符串中有单引号应该怎样处理？ ‘’
#
#   - 字符串有哪些操作：
#       > 赋值操作 = ， 连接操作 +、
#       > 替换、查找、切割。

# %% [markdown]
# 字符串赋值操作：
# ---
# - 字符串的赋值操作和数值类型的赋值操作也是一样的。使用 =
#
#
# ```python
# info = '你好,世界!'
# ```

# %% [markdown]
# 程序输入：
# ---
# - 程序有可交互性 就是有输入和输出。
#  > 输出语句有print
#
#  > 输入语句有input
#
# - 输入语句input 系统默认是字符串类型
#  > input() 里面填写想要表达的字符串。
#
#
# ``` python3
#  input_info = input('请输入要输入的信息')
#  print(type(input_info))
# ```
#
# ![image.png](attachment:28085043-6f9f-4648-a3dc-4c0ad98be472.png)
#
#
# - 想要换行怎么办？
#
#
# ``` python3
#  input_info = input('请输入要输入的信息\n')
#  print(type(input_info))
# ```
#  ![image.png](attachment:f0f0aa0c-60b3-44b8-8747-00a98bf6d0da.png)
#
# 假如输入的是数字或者邮箱？电话？等等
# ---
# - 输入语句input 系统默认是字符串类型，如果输入的数字需要进行转换。
# - 输入分数值。
#
# ``` python3
#  input_info = int(input('请输入要输入的信息\n'))
#  print(type(input_info))
# ```
#
# ![image.png](attachment:fe15a276-83c4-40b9-b7f6-384e2f82de8d.png)
#
# - 运行示意图：
#
# ![image.png](attachment:881b083a-1b5f-40f6-8d95-5bf01c1920c8.png)

# %% [markdown]
# 字符串特殊性质：
# ---
#
#
# 1.  字符串有长度：
#  len(str01)
#
#
#
# 2.  字符串有index(下标)， 从字符串左边开始计算，index开始的数值为0 ， 最大数值为len(str)-1， index的数值不能随意编写，会出错。可以通过下标访问 str01[0] 获取的就是你， str[6] 获取的就是国
#     > str01 = '你好,我的祖国'
#
#     >> 你->index == 0
#     >> 国->index == 6
#
#
# 3.  字符串不支持通过下标的方式进行修改， 会产生相关错误。
#
# ![image.png](attachment:c137e4b1-30a6-4896-a157-e411f1b1d6be.png)
#
# 4. 字符串可以使用+号
#
# 5.  字符串到底能装多少字符?
# > 问题：
#
# ![image.png](attachment:83830638-1a63-4b5b-9b4d-5d8ee4931255.png)
#
# <hr>
# > 结果：
#
# ![image.png](attachment:a61b0517-4bb7-49de-8445-70f830d1aa11.png)
